# %%
import pandas as pd
import bs4
import requests

# %%
API_KEY = ''
REGION_CODES = ['%02d' % num for num in range(1,17)]
REGION_CODES
# Out:
# ['01',
#  '02',
#  '03',
#  '04',
#  '05',
#  '06',
#  '07',
#  '08',
#  '09',
#  '10',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16']

# %%
df = pd.DataFrame()


for REGION_CODE in REGION_CODES:
    
    PAGE = 1
    
    while True:
        
        # API 호출
        API = f'http://openapi.forest.go.kr/openapi/service/trailInfoService/getforeststoryservice?mntnInfoAraCd={REGION_CODE}&pageNo={PAGE}&serviceKey={API_KEY}'
        response = requests.get(API).text
        xmlobj = bs4.BeautifulSoup(response, 'lxml-xml')
        
        # ITEM 별로 파싱
        rows = xmlobj.findAll('item')
        
        if len(rows) == 0:
            print(f'== {PAGE}페이지에는 데이터가 존재하지 않습니다. 지역을 변경합니다. ==')
            break
        
        # 페이지별로 ITEM 수집
        rowList = []
        column_nameList = []
        valueList = []
        
        # Value 크롤링
        for i in range(0, len(rows)):
            columns = rows[i].find_all()

            for j in range(0, len(columns)):
                
                # 처음에 Column명 지정을 위함!
                if i == 0:
                    column_nameList.append(columns[j].name)
                
                eachColumn = columns[j].text
                valueList.append(eachColumn)
                
            rowList.append(valueList)
            valueList = []    
        
        # 데이터프레임에 추가
        tmp = pd.DataFrame(rowList, columns=column_nameList)
        df = df.append(tmp, ignore_index=True)
        
        print(f'== {REGION_CODE}지역 {PAGE}페이지 완료 ==')
        PAGE += 1
        
print('========== 크롤링 완료!! ==========')
# Out:
# == 01지역 1페이지 완료 ==
# == 01지역 2페이지 완료 ==
# == 01지역 3페이지 완료 ==
# 4에는 데이터가 존재하지 않습니다. 지역을 변경합니다.
# == 02지역 1페이지 완료 ==
# == 02지역 2페이지 완료 ==
# == 02지역 3페이지 완료 ==
# 4에는 데이터가 존재하지 않습니다. 지역을 변경합니다.
# == 03지역 1페이지 완료 ==
# == 03지역 2페이지 완료 ==
# == 03지역 3페이지 완료 ==
# 4에는 데이터가 존재하지 않습니다. 지역을 변경합니다.
# == 04지역 1페이지 완료 ==
# == 04지역 2페이지 완료 ==
# == 04지역 3페이지 완료 ==
# 4에는 데이터가 존재하지 않습니다. 지역을 변경합니다.
# == 05지역 1페이지 완료 ==
# 2에는 데이터가 존재하지 않습니다. 지역을 변경합니다.
# == 06지역 1페이지 완료 ==
# == 06지역 2페이지 완료 ==
# 3에는 데이터가 존재하지 않습니다. 지역을 변경합니다.
# == 07지역 1페이지 완료 ==
# == 07지역 2페이지 완료 ==
# == 07지역 3페이지 완료 ==
# 4에는 데이터가 존재하지 않습니다. 지역을 변경합니다.
# == 08지역 1페이지 완료 ==
# == 08지역 2페이지 완료 ==
# == 08지역 3페이지 완료 ==
# == 08지역 4페이지 완료 ==
# == 08지역 5페이지 완료 ==
# == 08지역 6페이지 완료 ==
# == 08지역 7페이지 완료 ==
# == 08지역 8페이지 완료 ==
# == 08지역 9페이지 완료 ==
# == 08지역 10페이지 완료 ==
# == 08지역 11페이지 완료 ==
# == 08지역 12페이지 완료 ==
# == 08지역 13페이지 완료 ==
# == 08지역 14페이지 완료 ==
# == 08지역 15페이지 완료 ==
# == 08지역 16페이지 완료 ==
# == 08지역 17페이지 완료 ==
# == 08지역 18페이지 완료 ==
# == 08지역 19페이지 완료 ==
# == 08지역 20페이지 완료 ==
# 21에는 데이터가 존재하지 않습니다. 지역을 변경합니다.
# == 09지역 1페이지 완료 ==
# == 09지역 2페이지 완료 ==
# == 09지역 3페이지 완료 ==
# == 09지역 4페이지 완료 ==
# == 09지역 5페이지 완료 ==
# == 09지역 6페이지 완료 ==
# == 09지역 7페이지 완료 ==
# == 09지역 8페이지 완료 ==
# == 09지역 9페이지 완료 ==
# == 09지역 10페이지 완료 ==
# == 09지역 11페이지 완료 ==
# == 09지역 12페이지 완료 ==
# == 09지역 13페이지 완료 ==
# == 09지역 14페이지 완료 ==
# == 09지역 15페이지 완료 ==
# == 09지역 16페이지 완료 ==
# == 09지역 17페이지 완료 ==
# == 09지역 18페이지 완료 ==
# == 09지역 19페이지 완료 ==
# == 09지역 20페이지 완료 ==
# == 09지역 21페이지 완료 ==
# == 09지역 22페이지 완료 ==
# == 09지역 23페이지 완료 ==
# == 09지역 24페이지 완료 ==
# == 09지역 25페이지 완료 ==
# == 09지역 26페이지 완료 ==
# == 09지역 27페이지 완료 ==
# == 09지역 28페이지 완료 ==
# == 09지역 29페이지 완료 ==
# == 09지역 30페이지 완료 ==
# == 09지역 31페이지 완료 ==
# 32에는 데이터가 존재하지 않습니다. 지역을 변경합니다.
# == 10지역 1페이지 완료 ==
# == 10지역 2페이지 완료 ==
# == 10지역 3페이지 완료 ==
# == 10지역 4페이지 완료 ==
# == 10지역 5페이지 완료 ==
# == 10지역 6페이지 완료 ==
# == 10지역 7페이지 완료 ==
# == 10지역 8페이지 완료 ==
# == 10지역 9페이지 완료 ==
# == 10지역 10페이지 완료 ==
# == 10지역 11페이지 완료 ==
# == 10지역 12페이지 완료 ==
# == 10지역 13페이지 완료 ==
# == 10지역 14페이지 완료 ==
# == 10지역 15페이지 완료 ==
# == 10지역 16페이지 완료 ==
# == 10지역 17페이지 완료 ==
# == 10지역 18페이지 완료 ==
# == 10지역 19페이지 완료 ==
# 20에는 데이터가 존재하지 않습니다. 지역을 변경합니다.
# == 11지역 1페이지 완료 ==
# == 11지역 2페이지 완료 ==
# == 11지역 3페이지 완료 ==
# == 11지역 4페이지 완료 ==
# == 11지역 5페이지 완료 ==
# == 11지역 6페이지 완료 ==
# == 11지역 7페이지 완료 ==
# == 11지역 8페이지 완료 ==
# == 11지역 9페이지 완료 ==
# == 11지역 10페이지 완료 ==
# 11에는 데이터가 존재하지 않습니다. 지역을 변경합니다.
# == 12지역 1페이지 완료 ==
# == 12지역 2페이지 완료 ==
# == 12지역 3페이지 완료 ==
# == 12지역 4페이지 완료 ==
# == 12지역 5페이지 완료 ==
# == 12지역 6페이지 완료 ==
# == 12지역 7페이지 완료 ==
# == 12지역 8페이지 완료 ==
# == 12지역 9페이지 완료 ==
# == 12지역 10페이지 완료 ==
# 11에는 데이터가 존재하지 않습니다. 지역을 변경합니다.
# == 13지역 1페이지 완료 ==
# == 13지역 2페이지 완료 ==
# == 13지역 3페이지 완료 ==
# == 13지역 4페이지 완료 ==
# == 13지역 5페이지 완료 ==
# == 13지역 6페이지 완료 ==
# == 13지역 7페이지 완료 ==
# == 13지역 8페이지 완료 ==
# == 13지역 9페이지 완료 ==
# == 13지역 10페이지 완료 ==
# == 13지역 11페이지 완료 ==
# == 13지역 12페이지 완료 ==
# == 13지역 13페이지 완료 ==
# == 13지역 14페이지 완료 ==
# == 13지역 15페이지 완료 ==
# == 13지역 16페이지 완료 ==
# == 13지역 17페이지 완료 ==
# 18에는 데이터가 존재하지 않습니다. 지역을 변경합니다.
# == 14지역 1페이지 완료 ==
# == 14지역 2페이지 완료 ==
# == 14지역 3페이지 완료 ==
# == 14지역 4페이지 완료 ==
# == 14지역 5페이지 완료 ==
# == 14지역 6페이지 완료 ==
# == 14지역 7페이지 완료 ==
# == 14지역 8페이지 완료 ==
# == 14지역 9페이지 완료 ==
# == 14지역 10페이지 완료 ==
# == 14지역 11페이지 완료 ==
# == 14지역 12페이지 완료 ==
# == 14지역 13페이지 완료 ==
# == 14지역 14페이지 완료 ==
# == 14지역 15페이지 완료 ==
# == 14지역 16페이지 완료 ==
# == 14지역 17페이지 완료 ==
# == 14지역 18페이지 완료 ==
# == 14지역 19페이지 완료 ==
# == 14지역 20페이지 완료 ==
# == 14지역 21페이지 완료 ==
# == 14지역 22페이지 완료 ==
# == 14지역 23페이지 완료 ==
# == 14지역 24페이지 완료 ==
# == 14지역 25페이지 완료 ==
# == 14지역 26페이지 완료 ==
# == 14지역 27페이지 완료 ==
# == 14지역 28페이지 완료 ==
# 29에는 데이터가 존재하지 않습니다. 지역을 변경합니다.
# == 15지역 1페이지 완료 ==
# == 15지역 2페이지 완료 ==
# == 15지역 3페이지 완료 ==
# == 15지역 4페이지 완료 ==
# == 15지역 5페이지 완료 ==
# == 15지역 6페이지 완료 ==
# == 15지역 7페이지 완료 ==
# == 15지역 8페이지 완료 ==
# == 15지역 9페이지 완료 ==
# == 15지역 10페이지 완료 ==
# == 15지역 11페이지 완료 ==
# == 15지역 12페이지 완료 ==
# == 15지역 13페이지 완료 ==
# == 15지역 14페이지 완료 ==
# == 15지역 15페이지 완료 ==
# == 15지역 16페이지 완료 ==
# == 15지역 17페이지 완료 ==
# == 15지역 18페이지 완료 ==
# == 15지역 19페이지 완료 ==
# == 15지역 20페이지 완료 ==
# == 15지역 21페이지 완료 ==
# == 15지역 22페이지 완료 ==
# == 15지역 23페이지 완료 ==
# == 15지역 24페이지 완료 ==
# 25에는 데이터가 존재하지 않습니다. 지역을 변경합니다.
# == 16지역 1페이지 완료 ==
# == 16지역 2페이지 완료 ==
# 3에는 데이터가 존재하지 않습니다. 지역을 변경합니다.

# %%
column_names = pd.read_excel('../input/산악투어_컬럼명.xlsx')
columns_names_dict = {column_names.loc[idx, '영어변수명'] : column_names.loc[idx, '한글변수명'] for idx in range(column_names.shape[0])}
df.columns = [columns_names_dict[column] for column in df.columns]
df
# Out:
#                                               주변관광정보이미지  \
# 0        http://www.forest.go.kr/swf/foreston/mountain/
# 1     http://www.forest.go.kr/swf/foreston/mountain/...
# 2        http://www.forest.go.kr/swf/foreston/mountain/
# 3        http://www.forest.go.kr/swf/foreston/mountain/
# 4        http://www.forest.go.kr/swf/foreston/mountain/
# ...                                                 ...
# 1704     http://www.forest.go.kr/swf/foreston/mountain/
# 1705     http://www.forest.go.kr/swf/foreston/mountain/
# 1706     http://www.forest.go.kr/swf/foreston/mountain/
# 1707     http://www.forest.go.kr/swf/foreston/mountain/
# 1708  http://www.forest.go.kr/swf/foreston/mountain/...
#
#                                                주변관광정보설명  \
# 0     약사사 3층석탑 (서울시 유형문화재 제 39호)-단층기단 위에 화강석으로 축조한 4...
# 1     ● 숙식 및 기타 정보<BR>야영장이나 자연휴양림 같은 특기할 만한 숙박시설이 없다...
# 2                                         <p>&nbsp;</p>
# 3                             양천 고성지 사적 372호, 소악루, 양천향교
# 4                                            &amp;nbsp;
# ...                                                 ...
# 1704
# 1705                                         &amp;#160;
# 1706                                         &amp;nbsp;
# 1707                                         &amp;#160;
# 1708  ● 숙식 및 기타정보<BR>제주나 서귀포에 숙박시설이 많이 있다. 시내에서 숙식한 ...
#
#                                         산정보주변관광정보기타코스설명 산행포인트설명  \
# 0                                            &amp;nbsp;
# 1     ① 사당동 대학촌-333봉-414봉-559봉-연주암-정상-장군바위-장군바위골-과천 ...
# 2                                         <p>&nbsp;</p>
# 3                                            &amp;#160;
# 4                                            &amp;nbsp;
# ...                                                 ...     ...
# 1704
# 1705                                         &amp;#160;
# 1706                                         &amp;nbsp;
# 1707                                         &amp;#160;
# 1708  ① 어리목광장-사제비동산-만세동산-윗세오름(총 2시간 소요)<BR>② 1100도로-...
#
#                                         100대명산 지도명(이미지)  \
# 0        http://www.forest.go.kr/swf/foreston/mountain/
# 1     http://www.forest.go.kr/swf/foreston/mountain/...
# 2        http://www.forest.go.kr/swf/foreston/mountain/
# 3        http://www.forest.go.kr/swf/foreston/mountain/
# 4        http://www.forest.go.kr/swf/foreston/mountain/
# ...                                                 ...
# 1704     http://www.forest.go.kr/swf/foreston/mountain/
# 1705     http://www.forest.go.kr/swf/foreston/mountain/
# 1706     http://www.forest.go.kr/swf/foreston/mountain/
# 1707     http://www.forest.go.kr/swf/foreston/mountain/
# 1708  http://www.forest.go.kr/swf/foreston/mountain/...
#
#                                             100대명산 선정이유  \
# 0                                            &amp;nbsp;
# 1     예로부터 경기 5악의 하나로서 경관이 수려하며, 도심지 가까이 위치한 도시자연공원(...
# 2                                         <p>&nbsp;</p>
# 3                                            &amp;#160;
# 4                                            &amp;nbsp;
# ...                                                 ...
# 1704
# 1705                                         &amp;#160;
# 1706                                         &amp;nbsp;
# 1707                                         &amp;#160;
# 1708  남한에서 가장 높은 우리나라 3대 영산의 하나로 산마루에는 분화구인 백록담이 있고 ...
#
#                                                  산정보이미지       산코드  \
# 0     http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20001457
# 1     http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20000059
# 2     http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20001047
# 3     http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  40006648
# 4     http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20000133
# ...                                                 ...       ...
# 1704  http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20001540
# 1705  http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20001541
# 1706  http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20001019
# 1707  http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20001544
# 1708  http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20000661
#
#                                               산정보개관(개관)  \
# 0     &amp;nbsp;&lt;span class="Apple-style-span" st...
# 1     &lt;광화문 해태 세우게한 화성의 극치&gt;<BR>옛 과천현의 진산이지만 정면은...
# 2                                         <p>&nbsp;</p>
# 3                                            &amp;#160;
# 4                                            &amp;nbsp;
# ...                                                 ...
# 1704  &amp;#160;서귀포시 영천동 서귀포산업과학고등학교 남동쪽에 위치한 오름으로, ...
# 1705  &amp;nbsp;관광객들이나 시민들이 아침 일찍 일출을 보며 산책로로 좋아하는 곳...
# 1706                                         &amp;nbsp;
# 1707  보는 방향에 따라 그 모습을 달리한다. 남동쪽에서 보는 왕릉 같은 가지런한 모양에 ...
# 1708  &lt;한라산이 곧 제주도다&gt;<BR>한반도 남쪽의 최고봉, 해발 1950m의 ...
#
#                                            상세정보내용(상세정보)  ...            전화번호  \
# 0                                            &amp;nbsp;  ...    02-2600-6076
# 1     관악산은 서울시 관악구와 금천구, 경기도 과천시와 안양시에 걸쳐 있어 북한산,도봉산...  ...
# 2     <p>구룡산(九龍山) 정상은 해발307.7m의 서울특별시 서초구 염곡동, 내곡동, ...  ...
# 3     &amp;nbsp;궁산은 궁산이란 이름 외에 파산, 성산, 진산, 관산등의 이름을 ...  ...
# 4     산이라고 하기에는 염치가 없을 정도로 나즈막한 높이의 대모산은 서울시 강남구에 위치...  ...
# ...                                                 ...  ...             ...
# 1704                                                     ...  064-710-3851~3
# 1705                                         &amp;#160;  ...  064-710-3851~3
# 1706  구좌읍 송당리 동족에 비자림(돌오름)과 용눈이오름 사이에 우뚝 솟아있는 매끈한 풀밭...  ...
# 1707                                         &amp;#160;  ...  064-710-3851~3
# 1708  한라산은 우리나라 최남단에 위치해 있으면서 남한에서 가장 높은 산이다. 해발 195...  ...
#
#                                             산정보지도다운로드파일 산정보관리주체명(관리주체)  \
# 0        http://www.forest.go.kr/swf/foreston/mountain/      서울특별시 강서구
# 1     http://www.forest.go.kr/swf/foreston/mountain/...
# 2        http://www.forest.go.kr/swf/foreston/mountain/
# 3        http://www.forest.go.kr/swf/foreston/mountain/            서울시
# 4        http://www.forest.go.kr/swf/foreston/mountain/
# ...                                                 ...            ...
# 1704     http://www.forest.go.kr/swf/foreston/mountain/            제주도
# 1705     http://www.forest.go.kr/swf/foreston/mountain/            제주도
# 1706     http://www.forest.go.kr/swf/foreston/mountain/
# 1707     http://www.forest.go.kr/swf/foreston/mountain/            제주도
# 1708  http://www.forest.go.kr/swf/foreston/mountain/...
#
#                      산정보소재지(소재지)  \
# 0                      서울특별시 강서구
# 1     서울특별시 관악구ㆍ금천구, 경기도 안양시ㆍ과천시
# 2     서울특별시 서초구 염곡동ㆍ내곡동, 강남구 개포동
# 3                  서울특별시 강서구 가양동
# 4                      서울특별시 강남구
# ...                          ...
# 1704                    제주도 서귀포시
# 1705       제주도 제주시 조천읍 신촌리, 삼양일동
# 1706             제주도 제주시 구좌읍 세화리
# 1707                 제주도 제주시 구좌읍
# 1708               제주도 제주시, 서귀포시
#
#                                                 교통정보이미지       산명  \
# 0        http://www.forest.go.kr/swf/foreston/mountain/      개화산
# 1     http://www.forest.go.kr/swf/foreston/mountain/...      관악산
# 2        http://www.forest.go.kr/swf/foreston/mountain/      구룡산
# 3        http://www.forest.go.kr/swf/foreston/mountain/       궁산
# 4        http://www.forest.go.kr/swf/foreston/mountain/      대모산
# ...                                                 ...      ...
# 1704     http://www.forest.go.kr/swf/foreston/mountain/      영천악
# 1705     http://www.forest.go.kr/swf/foreston/mountain/  원당봉(삼양)
# 1706     http://www.forest.go.kr/swf/foreston/mountain/      월랑봉
# 1707     http://www.forest.go.kr/swf/foreston/mountain/      은월봉
# 1708  http://www.forest.go.kr/swf/foreston/mountain/...      한라산
#
#                                                   산정보부제  \
# 0     http://www.gangseo.seoul.kr/portal/munhwa/inde...
# 1                                    수차례 화마가 쓸고 갔던 불의 산
# 2
# 3
# 4                                       산이라 하기에는 염치 없지만
# ...                                                 ...
# 1704                             http://jejutour.go.kr/
# 1705                             http://jejutour.go.kr/
# 1706
# 1707                             http://jejutour.go.kr/
# 1708                              화산이 잉태한 남한 최고(最高)의 영산
#
#                                     대중교통정보설명(교통정보 대중교통) 대중교통정보설명(교통정보 대중교통)  \
# 0                                            &amp;nbsp;
# 1     지하철이 가장 편리하다. 서울대 방면은 2호선 신림역과 봉천역, 과천 방면은 4호선...
# 2                                         <p>&nbsp;</p>
# 3                                            &amp;#160;
# 4                                            &amp;nbsp;
# ...                                                 ...                 ...
# 1704
# 1705                                         &amp;#160;
# 1706                                         &amp;nbsp;
# 1707                                         &amp;#160;
# 1708  제주시외버스터미널이 기점이다. 이곳에서 각 들머리로 가는 버스가 많이 있다.<BR>...
#
#                                              추천코스이미지
# 0     http://www.forest.go.kr/swf/foreston/mountain/
# 1     http://www.forest.go.kr/swf/foreston/mountain/
# 2     http://www.forest.go.kr/swf/foreston/mountain/
# 3     http://www.forest.go.kr/swf/foreston/mountain/
# 4     http://www.forest.go.kr/swf/foreston/mountain/
# ...                                              ...
# 1704  http://www.forest.go.kr/swf/foreston/mountain/
# 1705  http://www.forest.go.kr/swf/foreston/mountain/
# 1706  http://www.forest.go.kr/swf/foreston/mountain/
# 1707  http://www.forest.go.kr/swf/foreston/mountain/
# 1708  http://www.forest.go.kr/swf/foreston/mountain/
#
# [1709 rows x 21 columns]

# %%
df = df.drop_duplicates().reset_index(drop=True)
df
# Out:
#                                               주변관광정보이미지  \
# 0        http://www.forest.go.kr/swf/foreston/mountain/
# 1     http://www.forest.go.kr/swf/foreston/mountain/...
# 2        http://www.forest.go.kr/swf/foreston/mountain/
# 3        http://www.forest.go.kr/swf/foreston/mountain/
# 4        http://www.forest.go.kr/swf/foreston/mountain/
# ...                                                 ...
# 1573     http://www.forest.go.kr/swf/foreston/mountain/
# 1574     http://www.forest.go.kr/swf/foreston/mountain/
# 1575     http://www.forest.go.kr/swf/foreston/mountain/
# 1576     http://www.forest.go.kr/swf/foreston/mountain/
# 1577  http://www.forest.go.kr/swf/foreston/mountain/...
#
#                                                주변관광정보설명  \
# 0     약사사 3층석탑 (서울시 유형문화재 제 39호)-단층기단 위에 화강석으로 축조한 4...
# 1     ● 숙식 및 기타 정보<BR>야영장이나 자연휴양림 같은 특기할 만한 숙박시설이 없다...
# 2                                         <p>&nbsp;</p>
# 3                             양천 고성지 사적 372호, 소악루, 양천향교
# 4                                            &amp;nbsp;
# ...                                                 ...
# 1573
# 1574                                         &amp;#160;
# 1575                                         &amp;nbsp;
# 1576                                         &amp;#160;
# 1577  ● 숙식 및 기타정보<BR>제주나 서귀포에 숙박시설이 많이 있다. 시내에서 숙식한 ...
#
#                                         산정보주변관광정보기타코스설명 산행포인트설명  \
# 0                                            &amp;nbsp;
# 1     ① 사당동 대학촌-333봉-414봉-559봉-연주암-정상-장군바위-장군바위골-과천 ...
# 2                                         <p>&nbsp;</p>
# 3                                            &amp;#160;
# 4                                            &amp;nbsp;
# ...                                                 ...     ...
# 1573
# 1574                                         &amp;#160;
# 1575                                         &amp;nbsp;
# 1576                                         &amp;#160;
# 1577  ① 어리목광장-사제비동산-만세동산-윗세오름(총 2시간 소요)<BR>② 1100도로-...
#
#                                         100대명산 지도명(이미지)  \
# 0        http://www.forest.go.kr/swf/foreston/mountain/
# 1     http://www.forest.go.kr/swf/foreston/mountain/...
# 2        http://www.forest.go.kr/swf/foreston/mountain/
# 3        http://www.forest.go.kr/swf/foreston/mountain/
# 4        http://www.forest.go.kr/swf/foreston/mountain/
# ...                                                 ...
# 1573     http://www.forest.go.kr/swf/foreston/mountain/
# 1574     http://www.forest.go.kr/swf/foreston/mountain/
# 1575     http://www.forest.go.kr/swf/foreston/mountain/
# 1576     http://www.forest.go.kr/swf/foreston/mountain/
# 1577  http://www.forest.go.kr/swf/foreston/mountain/...
#
#                                             100대명산 선정이유  \
# 0                                            &amp;nbsp;
# 1     예로부터 경기 5악의 하나로서 경관이 수려하며, 도심지 가까이 위치한 도시자연공원(...
# 2                                         <p>&nbsp;</p>
# 3                                            &amp;#160;
# 4                                            &amp;nbsp;
# ...                                                 ...
# 1573
# 1574                                         &amp;#160;
# 1575                                         &amp;nbsp;
# 1576                                         &amp;#160;
# 1577  남한에서 가장 높은 우리나라 3대 영산의 하나로 산마루에는 분화구인 백록담이 있고 ...
#
#                                                  산정보이미지       산코드  \
# 0     http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20001457
# 1     http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20000059
# 2     http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20001047
# 3     http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  40006648
# 4     http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20000133
# ...                                                 ...       ...
# 1573  http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20001540
# 1574  http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20001541
# 1575  http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20001019
# 1576  http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20001544
# 1577  http://www.forest.go.kr/newkfsweb/cmm/fms/getI...  20000661
#
#                                               산정보개관(개관)  \
# 0     &amp;nbsp;&lt;span class="Apple-style-span" st...
# 1     &lt;광화문 해태 세우게한 화성의 극치&gt;<BR>옛 과천현의 진산이지만 정면은...
# 2                                         <p>&nbsp;</p>
# 3                                            &amp;#160;
# 4                                            &amp;nbsp;
# ...                                                 ...
# 1573  &amp;#160;서귀포시 영천동 서귀포산업과학고등학교 남동쪽에 위치한 오름으로, ...
# 1574  &amp;nbsp;관광객들이나 시민들이 아침 일찍 일출을 보며 산책로로 좋아하는 곳...
# 1575                                         &amp;nbsp;
# 1576  보는 방향에 따라 그 모습을 달리한다. 남동쪽에서 보는 왕릉 같은 가지런한 모양에 ...
# 1577  &lt;한라산이 곧 제주도다&gt;<BR>한반도 남쪽의 최고봉, 해발 1950m의 ...
#
#                                            상세정보내용(상세정보)  ...            전화번호  \
# 0                                            &amp;nbsp;  ...    02-2600-6076
# 1     관악산은 서울시 관악구와 금천구, 경기도 과천시와 안양시에 걸쳐 있어 북한산,도봉산...  ...
# 2     <p>구룡산(九龍山) 정상은 해발307.7m의 서울특별시 서초구 염곡동, 내곡동, ...  ...
# 3     &amp;nbsp;궁산은 궁산이란 이름 외에 파산, 성산, 진산, 관산등의 이름을 ...  ...
# 4     산이라고 하기에는 염치가 없을 정도로 나즈막한 높이의 대모산은 서울시 강남구에 위치...  ...
# ...                                                 ...  ...             ...
# 1573                                                     ...  064-710-3851~3
# 1574                                         &amp;#160;  ...  064-710-3851~3
# 1575  구좌읍 송당리 동족에 비자림(돌오름)과 용눈이오름 사이에 우뚝 솟아있는 매끈한 풀밭...  ...
# 1576                                         &amp;#160;  ...  064-710-3851~3
# 1577  한라산은 우리나라 최남단에 위치해 있으면서 남한에서 가장 높은 산이다. 해발 195...  ...
#
#                                             산정보지도다운로드파일 산정보관리주체명(관리주체)  \
# 0        http://www.forest.go.kr/swf/foreston/mountain/      서울특별시 강서구
# 1     http://www.forest.go.kr/swf/foreston/mountain/...
# 2        http://www.forest.go.kr/swf/foreston/mountain/
# 3        http://www.forest.go.kr/swf/foreston/mountain/            서울시
# 4        http://www.forest.go.kr/swf/foreston/mountain/
# ...                                                 ...            ...
# 1573     http://www.forest.go.kr/swf/foreston/mountain/            제주도
# 1574     http://www.forest.go.kr/swf/foreston/mountain/            제주도
# 1575     http://www.forest.go.kr/swf/foreston/mountain/
# 1576     http://www.forest.go.kr/swf/foreston/mountain/            제주도
# 1577  http://www.forest.go.kr/swf/foreston/mountain/...
#
#                      산정보소재지(소재지)  \
# 0                      서울특별시 강서구
# 1     서울특별시 관악구ㆍ금천구, 경기도 안양시ㆍ과천시
# 2     서울특별시 서초구 염곡동ㆍ내곡동, 강남구 개포동
# 3                  서울특별시 강서구 가양동
# 4                      서울특별시 강남구
# ...                          ...
# 1573                    제주도 서귀포시
# 1574       제주도 제주시 조천읍 신촌리, 삼양일동
# 1575             제주도 제주시 구좌읍 세화리
# 1576                 제주도 제주시 구좌읍
# 1577               제주도 제주시, 서귀포시
#
#                                                 교통정보이미지       산명  \
# 0        http://www.forest.go.kr/swf/foreston/mountain/      개화산
# 1     http://www.forest.go.kr/swf/foreston/mountain/...      관악산
# 2        http://www.forest.go.kr/swf/foreston/mountain/      구룡산
# 3        http://www.forest.go.kr/swf/foreston/mountain/       궁산
# 4        http://www.forest.go.kr/swf/foreston/mountain/      대모산
# ...                                                 ...      ...
# 1573     http://www.forest.go.kr/swf/foreston/mountain/      영천악
# 1574     http://www.forest.go.kr/swf/foreston/mountain/  원당봉(삼양)
# 1575     http://www.forest.go.kr/swf/foreston/mountain/      월랑봉
# 1576     http://www.forest.go.kr/swf/foreston/mountain/      은월봉
# 1577  http://www.forest.go.kr/swf/foreston/mountain/...      한라산
#
#                                                   산정보부제  \
# 0     http://www.gangseo.seoul.kr/portal/munhwa/inde...
# 1                                    수차례 화마가 쓸고 갔던 불의 산
# 2
# 3
# 4                                       산이라 하기에는 염치 없지만
# ...                                                 ...
# 1573                             http://jejutour.go.kr/
# 1574                             http://jejutour.go.kr/
# 1575
# 1576                             http://jejutour.go.kr/
# 1577                              화산이 잉태한 남한 최고(最高)의 영산
#
#                                     대중교통정보설명(교통정보 대중교통) 대중교통정보설명(교통정보 대중교통)  \
# 0                                            &amp;nbsp;
# 1     지하철이 가장 편리하다. 서울대 방면은 2호선 신림역과 봉천역, 과천 방면은 4호선...
# 2                                         <p>&nbsp;</p>
# 3                                            &amp;#160;
# 4                                            &amp;nbsp;
# ...                                                 ...                 ...
# 1573
# 1574                                         &amp;#160;
# 1575                                         &amp;nbsp;
# 1576                                         &amp;#160;
# 1577  제주시외버스터미널이 기점이다. 이곳에서 각 들머리로 가는 버스가 많이 있다.<BR>...
#
#                                              추천코스이미지
# 0     http://www.forest.go.kr/swf/foreston/mountain/
# 1     http://www.forest.go.kr/swf/foreston/mountain/
# 2     http://www.forest.go.kr/swf/foreston/mountain/
# 3     http://www.forest.go.kr/swf/foreston/mountain/
# 4     http://www.forest.go.kr/swf/foreston/mountain/
# ...                                              ...
# 1573  http://www.forest.go.kr/swf/foreston/mountain/
# 1574  http://www.forest.go.kr/swf/foreston/mountain/
# 1575  http://www.forest.go.kr/swf/foreston/mountain/
# 1576  http://www.forest.go.kr/swf/foreston/mountain/
# 1577  http://www.forest.go.kr/swf/foreston/mountain/
#
# [1578 rows x 21 columns]

# %%
df.to_excel('../output/산정보_API.xlsx', index=False)
